# %%
from bs4 import BeautifulSoup
import requests
html = requests.get("http://craftcans.com/db.php?search=all&sort=beerid&ord=desc&view=text")
html_soup = BeautifulSoup(html, 'html5lib')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-e0b117e41035> in <module>()
#       2 import requests
#       3 html = requests.get("http://craftcans.com/db.php?search=all&sort=beerid&ord=desc&view=text")
# ----> 4 html_soup = BeautifulSoup(html, 'html5lib')
#
# /home/bhumihar/anaconda3/lib/python3.5/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     190         if hasattr(markup, 'read'):        # It's a file-type object.
#     191             markup = markup.read()
# --> 192         elif len(markup) <= 256 and (
#     193                 (isinstance(markup, bytes) and not b'<' in markup)
#     194                 or (isinstance(markup, str) and not '<' in markup)
#
# TypeError: object of type 'Response' has no len()

# %%
from bs4 import BeautifulSoup
import requests
html = requests.get("http://craftcans.com/db.php?search=all&sort=beerid&ord=desc&view=text")
html_soup = BeautifulSoup(html, 'html5lib')

# %%
import urlopen

# %%
from bs4 import BeautifulSoup
import requests
html = urlopen("http://craftcans.com/db.php?search=all&sort=beerid&ord=desc&view=text")
html_soup = BeautifulSoup(html, 'html5lib')

# %%
from urllib.request import urlopen
 
from bs4 import BeautifulSoup
import pandas as pd
import re
html = urlopen("http://craftcans.com/db.php?search=all&sort=beerid&ord=desc&view=text")
html_soup = BeautifulSoup(html, 'html.parser')

# %%
html = urlopen("http://craftcans.com/db.php?search=all&sort=beerid&ord=desc&view=text")
html_soup = BeautifulSoup(html, 'html.parser')

# %%
html_soup

# %%
html_soup.find('td')

# %%
html_soup.find('tr')

# %%
html_soup.findall('tr')

# %%
html_soup.findAll('tr')

# %%
import re
str1 = "2345"
r = re.match("^(\d{1,4})\.$", str1)

# %%
r

# %%
r

# %%
import re
str1 = 2345
re.match("^(\d{1,4})\.$", str1)

# %%
import re
str1 = '2345'
r = re.match("^(\d{1,4})$", str1)

# %%
r

# %%
r.groups()

# %%
r.group(1)

# %%
r.group(2)

# %%
import re
str1 = '2345 hgfc'
r = re.match("^(\d{1,4})$", str1)

# %%
r.groups()

# %%
def get_all_beers(html_soup):
    beers = []
    all_rows_in_html_page = html_soup.findAll("tr")
    for table_row in all_rows_in_html_page:
        if is_beer_entry(table_row):
            row_cells = table_row.findAll("td")
            beer_entry = {
                "id": get_beer_id(row_cells[0].text),
                "name": row_cells[1].text,
                "brewery_name": row_cells[2].text,
                "brewery_location": row_cells[3].text,
                "style": row_cells[4].text,
                "size": row_cells[5].text,
                "abv": row_cells[6].text,    
                "ibu": row_cells[7].text
            }
            beers.append(beer_entry)
    return beers

# %%
# Determines if a table_row is a beer entry
def is_beer_entry(table_row):
    row_cells = table_row.findAll("td")
    beer_id = get_beer_id(row_cells[0].text)
    return ( len(row_cells) == 8 and beer_id )
 
# Return the beer entry numerical identifier from the "Entry" column.
def get_beer_id(cell_value):
    r = re.match("^(\d{1,4})\.$", cell_value)
    if r and len(r.groups()) == 1:
        beer_id = r.group(1)
        return int(beer_id)
    else:
        return None

# %%
html = urlopen("http://craftcans.com/db.php?search=all&sort=beerid&ord=desc&view=text")
html_soup = BeautifulSoup(html, 'html.parser')
beers_list = get_all_beers(html_soup)

# %%
df = pd.DataFrame(beers_list)
df.head(5)

# %%
df

# %%
all_rows_in_html_page = html_soup.findAll("tr")
    for table_row in all_rows_in_html_page:
        row_cells = table_row.findAll("td")

# %%
all_rows_in_html_page = html_soup.findAll("tr")
for table_row in all_rows_in_html_page:
    row_cells = table_row.findAll("td")

# %%
row_cells

# %%
beer_id = row_cells[0].text

# %%
beer_id

# %%
all_rows_in_html_page = html_soup.findAll("tr")
id_array =[]
for table_row in all_rows_in_html_page:
    row_cells = table_row.findAll("td")
    c = row_cells[0].text
    r = re.match("^(\d{1,4})\.$", cell_value)
    if r and len(r.groups()) == 1:
        beer_id = r.group(1)
        id_array.append(int(beer_id))

# %%
all_rows_in_html_page = html_soup.findAll("tr")
id_array =[]
for table_row in all_rows_in_html_page:
    row_cells = table_row.findAll("td")
    cell_value = row_cells[0].text
    r = re.match("^(\d{1,4})\.$", cell_value)
    if r and len(r.groups()) == 1:
        beer_entry = {
                "id": beer_id = r.group(1),
                "name": row_cells[1].text,
                "brewery_name": row_cells[2].text,
                "brewery_location": row_cells[3].text,
                "style": row_cells[4].text,
                "size": row_cells[5].text,
                "abv": row_cells[6].text,    
                "ibu": row_cells[7].text
            }
        id_array.append(beer_entry)

# %%
id_array

# %%
len(id_array)

# %%
len(all_rows_in_html_page)

# %%
all_rows_in_html_page = html_soup.findAll("tr")
id_array =[]
for table_row in all_rows_in_html_page:
    row_cells = table_row.findAll("td")
    cell_value = row_cells[0].text
    r = re.match("^(\d{1,4})\.$", cell_value)
    if r and len(r.groups()) == 1:
        beer_entry = {
                "id": r.group(1),
                "name": row_cells[1].text,
                "brewery_name": row_cells[2].text,
                "brewery_location": row_cells[3].text,
                "style": row_cells[4].text,
                "size": row_cells[5].text,
                "abv": row_cells[6].text,    
                "ibu": row_cells[7].text
            }
        id_array.append(beer_entry)

# %%
all_rows_in_html_page = html_soup.findAll("tr")
id_array =[]
for table_row in all_rows_in_html_page:
    row_cells = table_row.findAll("td")
    cell_value = row_cells[0].text
    r = re.match("^(\d{1,4})\.$", cell_value)
    if r and len(r.groups()) == 1:
        beer_entry = {
                "id": r.group(1),
                "name": row_cells[1].text,
                "brewery_name": row_cells[2].text,
                "brewery_location": row_cells[3].text,
                "style": row_cells[4].text,
                "size": row_cells[5].text,
                "abv": row_cells[6].text,    
                "ibu": row_cells[7].text
            }
        id_array.append(beer_entry)

# %%
id_array

# %%
from urllib.request import urlopen
 
from bs4 import BeautifulSoup
import pandas as pd
import re

def is_id(table_row) :
	table_data = table_row.findAll('td')
	id_data = table_data[0].text
	id_value = get_id(id_data)
	if (len(id_data)==8 and id_value) :
		return True
	else :
		return False
		
def get_id(id_data) :
	    val = re.match("^(\d{1,4})\.$", id_data)
	    if (val and len(val.groups())==1) :
	    	return val
	    else :
            return None ;
	     
	
def get_beer_data(html_data) :
	beer_data = []
	beer_tr = html_data.findAll('tr');
	for tablerow in beer_tr :
		if (is_id(tablerow)) :
			beer_v = beer_tr.findAll('td')
			beer_value = {
                "id": get_id(beer_v[0].text),
                "name": beer_v[1].text,
                "brewery_name": beer_v[2].text,
                "brewery_location": beer_v[3].text,
                "style": beer_v[4].text,
                "size": beer_v[5].text,
                "abv": beer_v[6].text,    
                "ibu": beer_v[7].text
            }
    	
			beer_data.append(beer_value)	
	return beer_data
	
	### Reading Url ####	
html = urlopen("http://craftcans.com/db.php?search=all&sort=beerid&ord=desc&view=text")
html_data = BeautifulSoup(html, 'html.parser')

	#### Get beer Data ####
beer_data_list = get_beer_data(html_data)

	##### Converting into dataframe####

beer_df = pd.DataFrame(beer_data_list)
beer_df

# %%
beer_df

# %%
beer_data_list

# %%
from urllib.request import urlopen
 
from bs4 import BeautifulSoup
import pandas as pd
import re

def is_id(table_row) :
    table_data = table_row.findAll('td')
    id_data = table_data[0].text
    id_value = get_id(id_data)
    if (len(id_data)==8 and id_value) :
        return True
    else :
        return False

def get_id(id_data) :
    val = re.match("^(\d{1,4})\.$", id_data)
    if (val and len(val.groups())==1) :
        return val
    else :
        return None ;
     
def get_beer_data(html_data) :
    beer_data = []
    beer_tr = html_data.findAll('tr');
    for tablerow in beer_tr :
        if (is_id(tablerow)) :
            beer_v = beer_tr.findAll('td')
            beer_value = {
                "id": get_id(beer_v[0].text),
                "name": beer_v[1].text,
                "brewery_name": beer_v[2].text,
                "brewery_location": beer_v[3].text,
                "style": beer_v[4].text,
                "size": beer_v[5].text,
                "abv": beer_v[6].text,    
                "ibu": beer_v[7].text
            }

            beer_data.append(beer_value)
    return beer_data

#### Get beer Data ####
beer_data_list = get_beer_data(html_data)

	##### Converting into dataframe####

beer_df = pd.DataFrame(beer_data_list)
beer_df

# %%
from urllib.request import urlopen
 
from bs4 import BeautifulSoup
import pandas as pd
import re

def is_id(table_row) :
    table_data = table_row.findAll('td')
    id_data = table_data[0].text
    id_value = get_id(id_data)
    if (len(table_data)==8 and id_value) :
        return True
    else :
        return False

def get_id(id_data) :
    val = re.match("^(\d{1,4})\.$", id_data)
    if (val and len(val.groups())==1) :
        return val
    else :
        return None ;
     
def get_beer_data(html_data) :
    beer_data = []
    beer_tr = html_data.findAll('tr');
    for tablerow in beer_tr :
        if (is_id(tablerow)) :
            beer_v = beer_tr.findAll('td')
            beer_value = {
                "id": get_id(beer_v[0].text),
                "name": beer_v[1].text,
                "brewery_name": beer_v[2].text,
                "brewery_location": beer_v[3].text,
                "style": beer_v[4].text,
                "size": beer_v[5].text,
                "abv": beer_v[6].text,    
                "ibu": beer_v[7].text
            }

            beer_data.append(beer_value)
    return beer_data

#### Get beer Data ####
beer_data_list = get_beer_data(html_data)

	##### Converting into dataframe####

beer_df = pd.DataFrame(beer_data_list)
beer_df

# %%
from urllib.request import urlopen
 
from bs4 import BeautifulSoup
import pandas as pd
import re

def is_id(table_row) :
    table_data = table_row.findAll('td')
    id_data = table_data[0].text
    id_value = get_id(id_data)
    if (len(table_data)==8 and id_value) :
        return True
    else :
        return False

def get_id(id_data) :
    val = re.match("^(\d{1,4})\.$", id_data)
    if (val and len(val.groups())==1) :
        return val
    else :
        return None ;
     
def get_beer_data(html_data) :
    beer_data = []
    beer_tr = html_data.findAll('tr');
    for tablerow in beer_tr :
        if (is_id(tablerow)) :
            beer_v = tablerow.findAll('td')
            beer_value = {
                "id": get_id(beer_v[0].text),
                "name": beer_v[1].text,
                "brewery_name": beer_v[2].text,
                "brewery_location": beer_v[3].text,
                "style": beer_v[4].text,
                "size": beer_v[5].text,
                "abv": beer_v[6].text,    
                "ibu": beer_v[7].text
            }

            beer_data.append(beer_value)
    return beer_data

#### Get beer Data ####
beer_data_list = get_beer_data(html_data)

	##### Converting into dataframe####

beer_df = pd.DataFrame(beer_data_list)
beer_df

# %%
from urllib.request import urlopen
 
from bs4 import BeautifulSoup
import pandas as pd
import re

def is_id(table_row) :
    table_data = table_row.findAll('td')
    id_data = table_data[0].text
    id_value = get_id(id_data)
    if (len(table_data)==8 and id_value) :
        return True
    else :
        return False

def get_id(id_data) :
    val = re.match("^(\d{1,4})\.$", id_data)
    if (val and len(val.groups())==1) :
        return int(val)
    else :
        return None ;
     
def get_beer_data(html_data) :
    beer_data = []
    beer_tr = html_data.findAll('tr');
    for tablerow in beer_tr :
        if (is_id(tablerow)) :
            beer_v = tablerow.findAll('td')
            beer_value = {
                "id": get_id(beer_v[0].text),
                "name": beer_v[1].text,
                "brewery_name": beer_v[2].text,
                "brewery_location": beer_v[3].text,
                "style": beer_v[4].text,
                "size": beer_v[5].text,
                "abv": beer_v[6].text,    
                "ibu": beer_v[7].text
            }

            beer_data.append(beer_value)
    return beer_data

#### Get beer Data ####
beer_data_list = get_beer_data(html_data)

	##### Converting into dataframe####

beer_df = pd.DataFrame(beer_data_list)
beer_df

# %%
from urllib.request import urlopen
 
from bs4 import BeautifulSoup
import pandas as pd
import re

def is_id(table_row) :
    table_data = table_row.findAll('td')
    id_data = table_data[0].text
    id_value = get_id(id_data)
    if (len(table_data)==8 and id_value) :
        return True
    else :
        return False

def get_id(id_data) :
    val = re.match("^(\d{1,4})\.$", id_data)
    if (val and len(val.groups())==1) :
        return int(val)
    else :
        return None ;
     
def get_beer_data(html_data) :
    beer_data = []
    beer_tr = html_data.findAll('tr');
    for tablerow in beer_tr :
        if (is_id(tablerow)) :
            beer_v = tablerow.findAll('td')
            beer_value = {
                "id": get_id(beer_v[0].text),
                "name": beer_v[1].text,
                "brewery_name": beer_v[2].text,
                "brewery_location": beer_v[3].text,
                "style": beer_v[4].text,
                "size": beer_v[5].text,
                "abv": beer_v[6].text,    
                "ibu": beer_v[7].text
            }

            beer_data.append(beer_value)
    return beer_data

#### Get beer Data ####
beer_data_list = get_beer_data(html_data)

	##### Converting into dataframe####

beer_df = pd.DataFrame(beer_data_list)
beer_df

# %%
from urllib.request import urlopen
 
from bs4 import BeautifulSoup
import pandas as pd
import re

def is_id(table_row) :
    table_data = table_row.findAll('td')
    id_data = table_data[0].text
    id_value = get_id(id_data)
    if (len(table_data)==8 and id_value) :
        return True
    else :
        return False

def get_id(id_data) :
    val = re.match("^(\d{1,4})\.$", id_data)
    if (val and len(val.groups())==1) :
        return int(val.group(1))
    else :
        return None ;
     
def get_beer_data(html_data) :
    beer_data = []
    beer_tr = html_data.findAll('tr');
    for tablerow in beer_tr :
        if (is_id(tablerow)) :
            beer_v = tablerow.findAll('td')
            beer_value = {
                "id": get_id(beer_v[0].text),
                "name": beer_v[1].text,
                "brewery_name": beer_v[2].text,
                "brewery_location": beer_v[3].text,
                "style": beer_v[4].text,
                "size": beer_v[5].text,
                "abv": beer_v[6].text,    
                "ibu": beer_v[7].text
            }

            beer_data.append(beer_value)
    return beer_data

#### Get beer Data ####
beer_data_list = get_beer_data(html_data)

	##### Converting into dataframe####

beer_df = pd.DataFrame(beer_data_list)
beer_df

# %%
beer_df.to_csv('beer.csv', sep='\t')

# %%
beer_df.to_csv('beer.csv', sep=',')
print ('Done.')

# %%
beer_df['id']

# %%
beer_df['id'].length

# %%
beer_df['id'].count()

# %%
beer_df.isnull().sum()

# %%
beer_df['ibu'].count()

# %%
beer_df.ibu[beer_df['ibu']=='N/A']

# %%
from bs4 import BeautifulSoup
import requests
html = requests.get("http://craftcans.com/db.php?search=all&sort=beerid&ord=desc&view=text")

# %%
html

# %%
html_soup = BeautifulSoup(html, 'html5lib')

# %%
from bs4 import BeautifulSoup
import requests
html = requests.get("http://craftcans.com/db.php?search=all&sort=beerid&ord=desc&view=text")
html_soup = BeautifulSoup(html, 'html5lib')

# %%
import pandas as pd

# %%
from urllib.request import urlopen
 
from bs4 import BeautifulSoup
import pandas as pd
import re
html = urlopen("http://craftcans.com/db.php?search=all&sort=beerid&ord=desc&view=text")
html_soup = BeautifulSoup(html, 'html.parser')

# %%
html_soup

# %%
pd.read_html(html_soup)

# %%
pd.read_html('CraftCans.com - Canned Beer Database - All Entries.html')

# %%
from urllib.request import urlopen
 
from bs4 import BeautifulSoup
import pandas as pd
import re

def is_id(table_row) :
    table_data = table_row.findAll('td')
    id_data = table_data[0].text
    id_value = get_id(id_data)
    if (len(table_data)==8 and id_value) :
        return True
    else :
        return False

def get_id(id_data) :
    val = re.match("^(\d{1,4})\.$", id_data)
    if (val and len(val.groups())==1) :
        return int(val.group(1))
    else :
        return None ;
     
def get_beer_data(html_data) :
    beer_data = []
    beer_tr = html_data.findAll('tr');
    for tablerow in beer_tr :
        if (is_id(tablerow)) :
            beer_v = tablerow.findAll('td')
            beer_value = {
                "id": get_id(beer_v[0].text),
                "name": beer_v[1].text,
                "brewery_name": beer_v[2].text,
                "brewery_location": beer_v[3].text,
                "style": beer_v[4].text,
                "size": beer_v[5].text,
                "abv": beer_v[6].text,    
                "ibu": beer_v[7].text
            }

            beer_data.append(beer_value)
    return beer_data

	### Reading Url ####	
html = urlopen("http://craftcans.com/db.php?search=all&sort=beerid&ord=desc&view=text")
html_data = BeautifulSoup(html, 'html.parser')

	#### Get beer Data ####
beer_data_list = get_beer_data(html_data)

	##### Converting into dataframe####

beer_df = pd.DataFrame(beer_data_list)

	##### Write data to csv ###### 
beer_df.to_csv('beer.csv', sep=',')
print ('Done.')

# %%
beer_df

# %%
def clean_abv(value) :
    val = str(value).split('%')[0]
    try :
        return float(val)/100;
    except :
        return None
beer_df['abv'] = beer_df['abv'].apply(clean_abv)

# %%
beer_df

# %%
beer_df['abv']

# %%
beer_df['ibu']

# %%
def str_to_int(value) :
    try :
        return int(value)
    except :
        return None
beer_df['ibu'] = beer_df['ibu'].apply(str_to_int)
beer_df['ibu']

# %%
beer_df
# Out:
#         abv     brewery_location                   brewery_name    ibu    id  \
# 0     0.045      Minneapolis, MN             NorthGate Brewing    50.0  2692
# 1     0.049      Minneapolis, MN             NorthGate Brewing    26.0  2691
# 2     0.048      Minneapolis, MN             NorthGate Brewing    19.0  2690
# 3     0.060      Minneapolis, MN             NorthGate Brewing    38.0  2689
# 4     0.060      Minneapolis, MN             NorthGate Brewing    25.0  2688
# 5     0.056      Minneapolis, MN             NorthGate Brewing    47.0  2687
# 6     0.080       Louisville, KY      Against the Grain Brewery   68.0  2686
# 7     0.125       Louisville, KY      Against the Grain Brewery   80.0  2685
# 8     0.077       Louisville, KY      Against the Grain Brewery   25.0  2684
# 9     0.042       Louisville, KY      Against the Grain Brewery   42.0  2683
# 10    0.050       Louisville, KY      Against the Grain Brewery   25.0  2682
# 11    0.066       Louisville, KY      Against the Grain Brewery   21.0  2681
# 12    0.040       Louisville, KY      Against the Grain Brewery   13.0  2680
# 13    0.055       Louisville, KY      Against the Grain Brewery   17.0  2679
# 14    0.076       Louisville, KY      Against the Grain Brewery   68.0  2678
# 15    0.051       Louisville, KY      Against the Grain Brewery   38.0  2677
# 16    0.065       Louisville, KY      Against the Grain Brewery    NaN  2676
# 17    0.060       Louisville, KY      Against the Grain Brewery   65.0  2675
# 18    0.050       Louisville, KY      Against the Grain Brewery   20.0  2674
# 19    0.052       Framingham, MA       Jack's Abby Craft Lagers   18.0  2673
# 20    0.048       Framingham, MA       Jack's Abby Craft Lagers   15.0  2672
# 21    0.072       Framingham, MA       Jack's Abby Craft Lagers   80.0  2671
# 22    0.067       Framingham, MA       Jack's Abby Craft Lagers   65.0  2670
# 23    0.049       Framingham, MA       Jack's Abby Craft Lagers   45.0  2669
# 24    0.080        San Diego, CA      Mike Hess Brewing Company  100.0  2668
# 25    0.075        San Diego, CA      Mike Hess Brewing Company   85.0  2667
# 26    0.060        San Diego, CA      Mike Hess Brewing Company   24.0  2666
# 27    0.080        San Diego, CA      Mike Hess Brewing Company  100.0  2664
# 28    0.063        San Diego, CA      Mike Hess Brewing Company   30.0  2663
# 29    0.058        San Diego, CA      Mike Hess Brewing Company   28.0  2662
# ...     ...                  ...                            ...    ...   ...
# 2380  0.057          Lahaina, HI           Maui Brewing Company   30.0    32
# 2381  0.062          Lahaina, HI           Maui Brewing Company   65.0    31
# 2382  0.049        Anchorage, AK  Sleeping Lady Brewing Company    NaN    30
# 2383  0.099             Reno, NV       Buckbean Brewing Company    NaN    29
# 2384  0.062             Reno, NV       Buckbean Brewing Company   42.0    28
# 2385  0.058             Reno, NV       Buckbean Brewing Company   35.0    27
# 2386  0.052             Reno, NV       Buckbean Brewing Company   40.0    26
# 2387  0.085       Santa Cruz, CA               Uncommon Brewers    NaN    25
# 2388  0.070        Pottstown, PA        Sly Fox Brewing Company  113.0    24
# 2389  0.053        Pottstown, PA        Sly Fox Brewing Company   21.0    23
# 2390  0.056        Pottstown, PA        Sly Fox Brewing Company   11.0    22
# 2391  0.049        Pottstown, PA        Sly Fox Brewing Company   44.0    21
# 2392  0.051        Pottstown, PA        Sly Fox Brewing Company   40.0    20
# 2393  0.040  Brooklyn Center, MN          Surly Brewing Company   37.0    19
# 2394  0.055  Brooklyn Center, MN          Surly Brewing Company   34.0    18
# 2395  0.051  Brooklyn Center, MN          Surly Brewing Company   45.0    17
# 2396  0.051  Brooklyn Center, MN          Surly Brewing Company   45.0    16
# 2397  0.097  Brooklyn Center, MN          Surly Brewing Company  120.0    15
# 2398  0.051  Brooklyn Center, MN          Surly Brewing Company   20.0    14
# 2399  0.067  Brooklyn Center, MN          Surly Brewing Company   33.0    13
# 2400  0.062  Brooklyn Center, MN          Surly Brewing Company   99.0    12
# 2401  0.083    San Francisco, CA         21st Amendment Brewery   35.0    11
# 2402  0.070    San Francisco, CA         21st Amendment Brewery   65.0    10
# 2403  0.049    San Francisco, CA         21st Amendment Brewery   17.0     9
# 2404  0.099         Longmont, CO            Oskar Blues Brewery   98.0     8
# 2405  0.053         Longmont, CO            Oskar Blues Brewery   35.0     7
# 2406  0.099         Longmont, CO            Oskar Blues Brewery  100.0     6
# 2407  0.080         Longmont, CO            Oskar Blues Brewery   35.0     5
# 2408  0.087         Longmont, CO            Oskar Blues Brewery   85.0     4
# 2409  0.065         Longmont, CO            Oskar Blues Brewery   65.0     1
#
#                                        name     size  \
# 0                              Get Together   16 oz.
# 1                             Maggie's Leap   16 oz.
# 2                                Wall's End   16 oz.
# 3                                   Pumpion   16 oz.
# 4                                Stronghold   16 oz.
# 5                               Parapet ESB   16 oz.
# 6                            Citra Ass Down   16 oz.
# 7                            London Balling   16 oz.
# 8                                      35 K   16 oz.
# 9                                    A Beer   16 oz.
# 10                          Rules are Rules   16 oz.
# 11                            Flesh Gourd'n   16 oz.
# 12                                 Sho'nuff   16 oz.
# 13                              Bloody Show   16 oz.
# 14                              Rico Sauvin   16 oz.
# 15                         Coq de la Marche   16 oz.
# 16                           Kamen Knuddeln   16 oz.
# 17                             Pile of Face   16 oz.
# 18                           The Brown Note   16 oz.
# 19                              House Lager   16 oz.
# 20                             Leisure Time  12 oz.
# 21                               Excess IPL   16 oz.
# 22                           Hoponius Union   12 oz.
# 23                                 Calyptra   12 oz.
# 24                           Habitus (2014)   16 oz.
# 25                                    Solis   16 oz.
# 26                                 Jucundus   16 oz.
# 27                                  Habitus   16 oz.
# 28                                  Grazias   16 oz.
# 29                                 Claritas   16 oz.
# ...                                     ...      ...
# 2380                         CoCoNut Porter   12 oz.
# 2381                          Big Swell IPA   12 oz.
# 2382              Urban Wilderness Pale Ale   12 oz.
# 2383             Very Noddy Lager (Current)   16 oz.
# 2384            Tule Duck Red Ale (Current)   16 oz.
# 2385  Original Orange Blossom Ale (Current)   16 oz.
# 2386            Black Noddy Lager (Current)   16 oz.
# 2387                           Siamese twin   16 oz.
# 2388                                113 IPA   12 oz.
# 2389                           Dunkel Lager   12 oz.
# 2390                       Royal Weisse Ale   12 oz.
# 2391                          Pikeland Pils   12 oz.
# 2392                       Phoenix Pale Ale   12 oz.
# 2393                          Bitter Brewer   16 oz.
# 2394                              SurlyFest   16 oz.
# 2395                          Coffee Bender   16 oz.
# 2396                                 Bender   16 oz.
# 2397                           Abrasive Ale   16 oz.
# 2398                                   Hell   16 oz.
# 2399                               CynicAle   16 oz.
# 2400                                Furious   16 oz.
# 2401                           Monk's Blood   12 oz.
# 2402                  Brew Free! or Die IPA   12 oz.
# 2403          Hell or High Watermelon Wheat   12 oz.
# 2404                Ten Fidy Imperial Stout   12 oz.
# 2405               Mama's Little Yella Pils   12 oz.
# 2406                     GUBNA Imperial IPA   12 oz.
# 2407                               Old Chub   12 oz.
# 2408                      Gordon Ale (2009)   12 oz.
# 2409                        Dale's Pale Ale   12 oz.
#
#                                     style
# 0                            American IPA
# 1                      Milk / Sweet Stout
# 2                       English Brown Ale
# 3                             Pumpkin Ale
# 4                         American Porter
# 5     Extra Special / Strong Bitter (ESB)
# 6          American Double / Imperial IPA
# 7                      English Barleywine
# 8                      Milk / Sweet Stout
# 9                 American Pale Ale (APA)
# 10                        German Pilsener
# 11                            Pumpkin Ale
# 12                       Belgian Pale Ale
# 13                       American Pilsner
# 14         American Double / Imperial IPA
# 15                 Saison / Farmhouse Ale
# 16                      American Wild Ale
# 17                           American IPA
# 18                      English Brown Ale
# 19             Keller Bier / Zwickel Bier
# 20                    American Pale Lager
# 21              American India Pale Lager
# 22              American India Pale Lager
# 23              American India Pale Lager
# 24         American Double / Imperial IPA
# 25                           American IPA
# 26                              Wheat Ale
# 27         American Double / Imperial IPA
# 28                              Cream Ale
# 29                                 Kölsch
# ...                                   ...
# 2380                      American Porter
# 2381                         American IPA
# 2382                     English Pale Ale
# 2383                          Schwarzbier
# 2384             American Amber / Red Ale
# 2385                 Herbed / Spiced Beer
# 2386                          Schwarzbier
# 2387                               Dubbel
# 2388                         American IPA
# 2389                  Munich Dunkel Lager
# 2390                           Hefeweizen
# 2391                      German Pilsener
# 2392              American Pale Ale (APA)
# 2393                       English Bitter
# 2394                             Rye Beer
# 2395                   American Brown Ale
# 2396                   American Brown Ale
# 2397       American Double / Imperial IPA
# 2398           Keller Bier / Zwickel Bier
# 2399               Saison / Farmhouse Ale
# 2400                         American IPA
# 2401                     Belgian Dark Ale
# 2402                         American IPA
# 2403               Fruit / Vegetable Beer
# 2404               Russian Imperial Stout
# 2405                       Czech Pilsener
# 2406       American Double / Imperial IPA
# 2407                         Scottish Ale
# 2408       American Double / Imperial IPA
# 2409              American Pale Ale (APA)
#
# [2410 rows x 8 columns]

# %%
beer_df = beer_df.rename(columns={'size':'size(oz)'})

# %%
beer_df
# Out:
#         abv     brewery_location                   brewery_name    ibu    id  \
# 0     0.045      Minneapolis, MN             NorthGate Brewing    50.0  2692
# 1     0.049      Minneapolis, MN             NorthGate Brewing    26.0  2691
# 2     0.048      Minneapolis, MN             NorthGate Brewing    19.0  2690
# 3     0.060      Minneapolis, MN             NorthGate Brewing    38.0  2689
# 4     0.060      Minneapolis, MN             NorthGate Brewing    25.0  2688
# 5     0.056      Minneapolis, MN             NorthGate Brewing    47.0  2687
# 6     0.080       Louisville, KY      Against the Grain Brewery   68.0  2686
# 7     0.125       Louisville, KY      Against the Grain Brewery   80.0  2685
# 8     0.077       Louisville, KY      Against the Grain Brewery   25.0  2684
# 9     0.042       Louisville, KY      Against the Grain Brewery   42.0  2683
# 10    0.050       Louisville, KY      Against the Grain Brewery   25.0  2682
# 11    0.066       Louisville, KY      Against the Grain Brewery   21.0  2681
# 12    0.040       Louisville, KY      Against the Grain Brewery   13.0  2680
# 13    0.055       Louisville, KY      Against the Grain Brewery   17.0  2679
# 14    0.076       Louisville, KY      Against the Grain Brewery   68.0  2678
# 15    0.051       Louisville, KY      Against the Grain Brewery   38.0  2677
# 16    0.065       Louisville, KY      Against the Grain Brewery    NaN  2676
# 17    0.060       Louisville, KY      Against the Grain Brewery   65.0  2675
# 18    0.050       Louisville, KY      Against the Grain Brewery   20.0  2674
# 19    0.052       Framingham, MA       Jack's Abby Craft Lagers   18.0  2673
# 20    0.048       Framingham, MA       Jack's Abby Craft Lagers   15.0  2672
# 21    0.072       Framingham, MA       Jack's Abby Craft Lagers   80.0  2671
# 22    0.067       Framingham, MA       Jack's Abby Craft Lagers   65.0  2670
# 23    0.049       Framingham, MA       Jack's Abby Craft Lagers   45.0  2669
# 24    0.080        San Diego, CA      Mike Hess Brewing Company  100.0  2668
# 25    0.075        San Diego, CA      Mike Hess Brewing Company   85.0  2667
# 26    0.060        San Diego, CA      Mike Hess Brewing Company   24.0  2666
# 27    0.080        San Diego, CA      Mike Hess Brewing Company  100.0  2664
# 28    0.063        San Diego, CA      Mike Hess Brewing Company   30.0  2663
# 29    0.058        San Diego, CA      Mike Hess Brewing Company   28.0  2662
# ...     ...                  ...                            ...    ...   ...
# 2380  0.057          Lahaina, HI           Maui Brewing Company   30.0    32
# 2381  0.062          Lahaina, HI           Maui Brewing Company   65.0    31
# 2382  0.049        Anchorage, AK  Sleeping Lady Brewing Company    NaN    30
# 2383  0.099             Reno, NV       Buckbean Brewing Company    NaN    29
# 2384  0.062             Reno, NV       Buckbean Brewing Company   42.0    28
# 2385  0.058             Reno, NV       Buckbean Brewing Company   35.0    27
# 2386  0.052             Reno, NV       Buckbean Brewing Company   40.0    26
# 2387  0.085       Santa Cruz, CA               Uncommon Brewers    NaN    25
# 2388  0.070        Pottstown, PA        Sly Fox Brewing Company  113.0    24
# 2389  0.053        Pottstown, PA        Sly Fox Brewing Company   21.0    23
# 2390  0.056        Pottstown, PA        Sly Fox Brewing Company   11.0    22
# 2391  0.049        Pottstown, PA        Sly Fox Brewing Company   44.0    21
# 2392  0.051        Pottstown, PA        Sly Fox Brewing Company   40.0    20
# 2393  0.040  Brooklyn Center, MN          Surly Brewing Company   37.0    19
# 2394  0.055  Brooklyn Center, MN          Surly Brewing Company   34.0    18
# 2395  0.051  Brooklyn Center, MN          Surly Brewing Company   45.0    17
# 2396  0.051  Brooklyn Center, MN          Surly Brewing Company   45.0    16
# 2397  0.097  Brooklyn Center, MN          Surly Brewing Company  120.0    15
# 2398  0.051  Brooklyn Center, MN          Surly Brewing Company   20.0    14
# 2399  0.067  Brooklyn Center, MN          Surly Brewing Company   33.0    13
# 2400  0.062  Brooklyn Center, MN          Surly Brewing Company   99.0    12
# 2401  0.083    San Francisco, CA         21st Amendment Brewery   35.0    11
# 2402  0.070    San Francisco, CA         21st Amendment Brewery   65.0    10
# 2403  0.049    San Francisco, CA         21st Amendment Brewery   17.0     9
# 2404  0.099         Longmont, CO            Oskar Blues Brewery   98.0     8
# 2405  0.053         Longmont, CO            Oskar Blues Brewery   35.0     7
# 2406  0.099         Longmont, CO            Oskar Blues Brewery  100.0     6
# 2407  0.080         Longmont, CO            Oskar Blues Brewery   35.0     5
# 2408  0.087         Longmont, CO            Oskar Blues Brewery   85.0     4
# 2409  0.065         Longmont, CO            Oskar Blues Brewery   65.0     1
#
#                                        name size(oz)  \
# 0                              Get Together   16 oz.
# 1                             Maggie's Leap   16 oz.
# 2                                Wall's End   16 oz.
# 3                                   Pumpion   16 oz.
# 4                                Stronghold   16 oz.
# 5                               Parapet ESB   16 oz.
# 6                            Citra Ass Down   16 oz.
# 7                            London Balling   16 oz.
# 8                                      35 K   16 oz.
# 9                                    A Beer   16 oz.
# 10                          Rules are Rules   16 oz.
# 11                            Flesh Gourd'n   16 oz.
# 12                                 Sho'nuff   16 oz.
# 13                              Bloody Show   16 oz.
# 14                              Rico Sauvin   16 oz.
# 15                         Coq de la Marche   16 oz.
# 16                           Kamen Knuddeln   16 oz.
# 17                             Pile of Face   16 oz.
# 18                           The Brown Note   16 oz.
# 19                              House Lager   16 oz.
# 20                             Leisure Time  12 oz.
# 21                               Excess IPL   16 oz.
# 22                           Hoponius Union   12 oz.
# 23                                 Calyptra   12 oz.
# 24                           Habitus (2014)   16 oz.
# 25                                    Solis   16 oz.
# 26                                 Jucundus   16 oz.
# 27                                  Habitus   16 oz.
# 28                                  Grazias   16 oz.
# 29                                 Claritas   16 oz.
# ...                                     ...      ...
# 2380                         CoCoNut Porter   12 oz.
# 2381                          Big Swell IPA   12 oz.
# 2382              Urban Wilderness Pale Ale   12 oz.
# 2383             Very Noddy Lager (Current)   16 oz.
# 2384            Tule Duck Red Ale (Current)   16 oz.
# 2385  Original Orange Blossom Ale (Current)   16 oz.
# 2386            Black Noddy Lager (Current)   16 oz.
# 2387                           Siamese twin   16 oz.
# 2388                                113 IPA   12 oz.
# 2389                           Dunkel Lager   12 oz.
# 2390                       Royal Weisse Ale   12 oz.
# 2391                          Pikeland Pils   12 oz.
# 2392                       Phoenix Pale Ale   12 oz.
# 2393                          Bitter Brewer   16 oz.
# 2394                              SurlyFest   16 oz.
# 2395                          Coffee Bender   16 oz.
# 2396                                 Bender   16 oz.
# 2397                           Abrasive Ale   16 oz.
# 2398                                   Hell   16 oz.
# 2399                               CynicAle   16 oz.
# 2400                                Furious   16 oz.
# 2401                           Monk's Blood   12 oz.
# 2402                  Brew Free! or Die IPA   12 oz.
# 2403          Hell or High Watermelon Wheat   12 oz.
# 2404                Ten Fidy Imperial Stout   12 oz.
# 2405               Mama's Little Yella Pils   12 oz.
# 2406                     GUBNA Imperial IPA   12 oz.
# 2407                               Old Chub   12 oz.
# 2408                      Gordon Ale (2009)   12 oz.
# 2409                        Dale's Pale Ale   12 oz.
#
#                                     style
# 0                            American IPA
# 1                      Milk / Sweet Stout
# 2                       English Brown Ale
# 3                             Pumpkin Ale
# 4                         American Porter
# 5     Extra Special / Strong Bitter (ESB)
# 6          American Double / Imperial IPA
# 7                      English Barleywine
# 8                      Milk / Sweet Stout
# 9                 American Pale Ale (APA)
# 10                        German Pilsener
# 11                            Pumpkin Ale
# 12                       Belgian Pale Ale
# 13                       American Pilsner
# 14         American Double / Imperial IPA
# 15                 Saison / Farmhouse Ale
# 16                      American Wild Ale
# 17                           American IPA
# 18                      English Brown Ale
# 19             Keller Bier / Zwickel Bier
# 20                    American Pale Lager
# 21              American India Pale Lager
# 22              American India Pale Lager
# 23              American India Pale Lager
# 24         American Double / Imperial IPA
# 25                           American IPA
# 26                              Wheat Ale
# 27         American Double / Imperial IPA
# 28                              Cream Ale
# 29                                 Kölsch
# ...                                   ...
# 2380                      American Porter
# 2381                         American IPA
# 2382                     English Pale Ale
# 2383                          Schwarzbier
# 2384             American Amber / Red Ale
# 2385                 Herbed / Spiced Beer
# 2386                          Schwarzbier
# 2387                               Dubbel
# 2388                         American IPA
# 2389                  Munich Dunkel Lager
# 2390                           Hefeweizen
# 2391                      German Pilsener
# 2392              American Pale Ale (APA)
# 2393                       English Bitter
# 2394                             Rye Beer
# 2395                   American Brown Ale
# 2396                   American Brown Ale
# 2397       American Double / Imperial IPA
# 2398           Keller Bier / Zwickel Bier
# 2399               Saison / Farmhouse Ale
# 2400                         American IPA
# 2401                     Belgian Dark Ale
# 2402                         American IPA
# 2403               Fruit / Vegetable Beer
# 2404               Russian Imperial Stout
# 2405                       Czech Pilsener
# 2406       American Double / Imperial IPA
# 2407                         Scottish Ale
# 2408       American Double / Imperial IPA
# 2409              American Pale Ale (APA)
#
# [2410 rows x 8 columns]

# %%
def strip_oz(value) :
    val = str(value).split('oz')[0]
    return val
beer_df['size(oz)'] = beer_df['size(oz)'].apply(strip_oz)

# %%
beer_df
# Out:
#         abv     brewery_location                   brewery_name    ibu    id  \
# 0     0.045      Minneapolis, MN             NorthGate Brewing    50.0  2692
# 1     0.049      Minneapolis, MN             NorthGate Brewing    26.0  2691
# 2     0.048      Minneapolis, MN             NorthGate Brewing    19.0  2690
# 3     0.060      Minneapolis, MN             NorthGate Brewing    38.0  2689
# 4     0.060      Minneapolis, MN             NorthGate Brewing    25.0  2688
# 5     0.056      Minneapolis, MN             NorthGate Brewing    47.0  2687
# 6     0.080       Louisville, KY      Against the Grain Brewery   68.0  2686
# 7     0.125       Louisville, KY      Against the Grain Brewery   80.0  2685
# 8     0.077       Louisville, KY      Against the Grain Brewery   25.0  2684
# 9     0.042       Louisville, KY      Against the Grain Brewery   42.0  2683
# 10    0.050       Louisville, KY      Against the Grain Brewery   25.0  2682
# 11    0.066       Louisville, KY      Against the Grain Brewery   21.0  2681
# 12    0.040       Louisville, KY      Against the Grain Brewery   13.0  2680
# 13    0.055       Louisville, KY      Against the Grain Brewery   17.0  2679
# 14    0.076       Louisville, KY      Against the Grain Brewery   68.0  2678
# 15    0.051       Louisville, KY      Against the Grain Brewery   38.0  2677
# 16    0.065       Louisville, KY      Against the Grain Brewery    NaN  2676
# 17    0.060       Louisville, KY      Against the Grain Brewery   65.0  2675
# 18    0.050       Louisville, KY      Against the Grain Brewery   20.0  2674
# 19    0.052       Framingham, MA       Jack's Abby Craft Lagers   18.0  2673
# 20    0.048       Framingham, MA       Jack's Abby Craft Lagers   15.0  2672
# 21    0.072       Framingham, MA       Jack's Abby Craft Lagers   80.0  2671
# 22    0.067       Framingham, MA       Jack's Abby Craft Lagers   65.0  2670
# 23    0.049       Framingham, MA       Jack's Abby Craft Lagers   45.0  2669
# 24    0.080        San Diego, CA      Mike Hess Brewing Company  100.0  2668
# 25    0.075        San Diego, CA      Mike Hess Brewing Company   85.0  2667
# 26    0.060        San Diego, CA      Mike Hess Brewing Company   24.0  2666
# 27    0.080        San Diego, CA      Mike Hess Brewing Company  100.0  2664
# 28    0.063        San Diego, CA      Mike Hess Brewing Company   30.0  2663
# 29    0.058        San Diego, CA      Mike Hess Brewing Company   28.0  2662
# ...     ...                  ...                            ...    ...   ...
# 2380  0.057          Lahaina, HI           Maui Brewing Company   30.0    32
# 2381  0.062          Lahaina, HI           Maui Brewing Company   65.0    31
# 2382  0.049        Anchorage, AK  Sleeping Lady Brewing Company    NaN    30
# 2383  0.099             Reno, NV       Buckbean Brewing Company    NaN    29
# 2384  0.062             Reno, NV       Buckbean Brewing Company   42.0    28
# 2385  0.058             Reno, NV       Buckbean Brewing Company   35.0    27
# 2386  0.052             Reno, NV       Buckbean Brewing Company   40.0    26
# 2387  0.085       Santa Cruz, CA               Uncommon Brewers    NaN    25
# 2388  0.070        Pottstown, PA        Sly Fox Brewing Company  113.0    24
# 2389  0.053        Pottstown, PA        Sly Fox Brewing Company   21.0    23
# 2390  0.056        Pottstown, PA        Sly Fox Brewing Company   11.0    22
# 2391  0.049        Pottstown, PA        Sly Fox Brewing Company   44.0    21
# 2392  0.051        Pottstown, PA        Sly Fox Brewing Company   40.0    20
# 2393  0.040  Brooklyn Center, MN          Surly Brewing Company   37.0    19
# 2394  0.055  Brooklyn Center, MN          Surly Brewing Company   34.0    18
# 2395  0.051  Brooklyn Center, MN          Surly Brewing Company   45.0    17
# 2396  0.051  Brooklyn Center, MN          Surly Brewing Company   45.0    16
# 2397  0.097  Brooklyn Center, MN          Surly Brewing Company  120.0    15
# 2398  0.051  Brooklyn Center, MN          Surly Brewing Company   20.0    14
# 2399  0.067  Brooklyn Center, MN          Surly Brewing Company   33.0    13
# 2400  0.062  Brooklyn Center, MN          Surly Brewing Company   99.0    12
# 2401  0.083    San Francisco, CA         21st Amendment Brewery   35.0    11
# 2402  0.070    San Francisco, CA         21st Amendment Brewery   65.0    10
# 2403  0.049    San Francisco, CA         21st Amendment Brewery   17.0     9
# 2404  0.099         Longmont, CO            Oskar Blues Brewery   98.0     8
# 2405  0.053         Longmont, CO            Oskar Blues Brewery   35.0     7
# 2406  0.099         Longmont, CO            Oskar Blues Brewery  100.0     6
# 2407  0.080         Longmont, CO            Oskar Blues Brewery   35.0     5
# 2408  0.087         Longmont, CO            Oskar Blues Brewery   85.0     4
# 2409  0.065         Longmont, CO            Oskar Blues Brewery   65.0     1
#
#                                        name size(oz)  \
# 0                              Get Together      16
# 1                             Maggie's Leap      16
# 2                                Wall's End      16
# 3                                   Pumpion      16
# 4                                Stronghold      16
# 5                               Parapet ESB      16
# 6                            Citra Ass Down      16
# 7                            London Balling      16
# 8                                      35 K      16
# 9                                    A Beer      16
# 10                          Rules are Rules      16
# 11                            Flesh Gourd'n      16
# 12                                 Sho'nuff      16
# 13                              Bloody Show      16
# 14                              Rico Sauvin      16
# 15                         Coq de la Marche      16
# 16                           Kamen Knuddeln      16
# 17                             Pile of Face      16
# 18                           The Brown Note      16
# 19                              House Lager      16
# 20                             Leisure Time      12
# 21                               Excess IPL      16
# 22                           Hoponius Union      12
# 23                                 Calyptra      12
# 24                           Habitus (2014)      16
# 25                                    Solis      16
# 26                                 Jucundus      16
# 27                                  Habitus      16
# 28                                  Grazias      16
# 29                                 Claritas      16
# ...                                     ...      ...
# 2380                         CoCoNut Porter      12
# 2381                          Big Swell IPA      12
# 2382              Urban Wilderness Pale Ale      12
# 2383             Very Noddy Lager (Current)      16
# 2384            Tule Duck Red Ale (Current)      16
# 2385  Original Orange Blossom Ale (Current)      16
# 2386            Black Noddy Lager (Current)      16
# 2387                           Siamese twin      16
# 2388                                113 IPA      12
# 2389                           Dunkel Lager      12
# 2390                       Royal Weisse Ale      12
# 2391                          Pikeland Pils      12
# 2392                       Phoenix Pale Ale      12
# 2393                          Bitter Brewer      16
# 2394                              SurlyFest      16
# 2395                          Coffee Bender      16
# 2396                                 Bender      16
# 2397                           Abrasive Ale      16
# 2398                                   Hell      16
# 2399                               CynicAle      16
# 2400                                Furious      16
# 2401                           Monk's Blood      12
# 2402                  Brew Free! or Die IPA      12
# 2403          Hell or High Watermelon Wheat      12
# 2404                Ten Fidy Imperial Stout      12
# 2405               Mama's Little Yella Pils      12
# 2406                     GUBNA Imperial IPA      12
# 2407                               Old Chub      12
# 2408                      Gordon Ale (2009)      12
# 2409                        Dale's Pale Ale      12
#
#                                     style
# 0                            American IPA
# 1                      Milk / Sweet Stout
# 2                       English Brown Ale
# 3                             Pumpkin Ale
# 4                         American Porter
# 5     Extra Special / Strong Bitter (ESB)
# 6          American Double / Imperial IPA
# 7                      English Barleywine
# 8                      Milk / Sweet Stout
# 9                 American Pale Ale (APA)
# 10                        German Pilsener
# 11                            Pumpkin Ale
# 12                       Belgian Pale Ale
# 13                       American Pilsner
# 14         American Double / Imperial IPA
# 15                 Saison / Farmhouse Ale
# 16                      American Wild Ale
# 17                           American IPA
# 18                      English Brown Ale
# 19             Keller Bier / Zwickel Bier
# 20                    American Pale Lager
# 21              American India Pale Lager
# 22              American India Pale Lager
# 23              American India Pale Lager
# 24         American Double / Imperial IPA
# 25                           American IPA
# 26                              Wheat Ale
# 27         American Double / Imperial IPA
# 28                              Cream Ale
# 29                                 Kölsch
# ...                                   ...
# 2380                      American Porter
# 2381                         American IPA
# 2382                     English Pale Ale
# 2383                          Schwarzbier
# 2384             American Amber / Red Ale
# 2385                 Herbed / Spiced Beer
# 2386                          Schwarzbier
# 2387                               Dubbel
# 2388                         American IPA
# 2389                  Munich Dunkel Lager
# 2390                           Hefeweizen
# 2391                      German Pilsener
# 2392              American Pale Ale (APA)
# 2393                       English Bitter
# 2394                             Rye Beer
# 2395                   American Brown Ale
# 2396                   American Brown Ale
# 2397       American Double / Imperial IPA
# 2398           Keller Bier / Zwickel Bier
# 2399               Saison / Farmhouse Ale
# 2400                         American IPA
# 2401                     Belgian Dark Ale
# 2402                         American IPA
# 2403               Fruit / Vegetable Beer
# 2404               Russian Imperial Stout
# 2405                       Czech Pilsener
# 2406       American Double / Imperial IPA
# 2407                         Scottish Ale
# 2408       American Double / Imperial IPA
# 2409              American Pale Ale (APA)
#
# [2410 rows x 8 columns]

# %%
beer_df.groupby('brewery_location')

# %%
beer_df
# Out:
#         abv     brewery_location                   brewery_name    ibu    id  \
# 0     0.045      Minneapolis, MN             NorthGate Brewing    50.0  2692
# 1     0.049      Minneapolis, MN             NorthGate Brewing    26.0  2691
# 2     0.048      Minneapolis, MN             NorthGate Brewing    19.0  2690
# 3     0.060      Minneapolis, MN             NorthGate Brewing    38.0  2689
# 4     0.060      Minneapolis, MN             NorthGate Brewing    25.0  2688
# 5     0.056      Minneapolis, MN             NorthGate Brewing    47.0  2687
# 6     0.080       Louisville, KY      Against the Grain Brewery   68.0  2686
# 7     0.125       Louisville, KY      Against the Grain Brewery   80.0  2685
# 8     0.077       Louisville, KY      Against the Grain Brewery   25.0  2684
# 9     0.042       Louisville, KY      Against the Grain Brewery   42.0  2683
# 10    0.050       Louisville, KY      Against the Grain Brewery   25.0  2682
# 11    0.066       Louisville, KY      Against the Grain Brewery   21.0  2681
# 12    0.040       Louisville, KY      Against the Grain Brewery   13.0  2680
# 13    0.055       Louisville, KY      Against the Grain Brewery   17.0  2679
# 14    0.076       Louisville, KY      Against the Grain Brewery   68.0  2678
# 15    0.051       Louisville, KY      Against the Grain Brewery   38.0  2677
# 16    0.065       Louisville, KY      Against the Grain Brewery    NaN  2676
# 17    0.060       Louisville, KY      Against the Grain Brewery   65.0  2675
# 18    0.050       Louisville, KY      Against the Grain Brewery   20.0  2674
# 19    0.052       Framingham, MA       Jack's Abby Craft Lagers   18.0  2673
# 20    0.048       Framingham, MA       Jack's Abby Craft Lagers   15.0  2672
# 21    0.072       Framingham, MA       Jack's Abby Craft Lagers   80.0  2671
# 22    0.067       Framingham, MA       Jack's Abby Craft Lagers   65.0  2670
# 23    0.049       Framingham, MA       Jack's Abby Craft Lagers   45.0  2669
# 24    0.080        San Diego, CA      Mike Hess Brewing Company  100.0  2668
# 25    0.075        San Diego, CA      Mike Hess Brewing Company   85.0  2667
# 26    0.060        San Diego, CA      Mike Hess Brewing Company   24.0  2666
# 27    0.080        San Diego, CA      Mike Hess Brewing Company  100.0  2664
# 28    0.063        San Diego, CA      Mike Hess Brewing Company   30.0  2663
# 29    0.058        San Diego, CA      Mike Hess Brewing Company   28.0  2662
# ...     ...                  ...                            ...    ...   ...
# 2380  0.057          Lahaina, HI           Maui Brewing Company   30.0    32
# 2381  0.062          Lahaina, HI           Maui Brewing Company   65.0    31
# 2382  0.049        Anchorage, AK  Sleeping Lady Brewing Company    NaN    30
# 2383  0.099             Reno, NV       Buckbean Brewing Company    NaN    29
# 2384  0.062             Reno, NV       Buckbean Brewing Company   42.0    28
# 2385  0.058             Reno, NV       Buckbean Brewing Company   35.0    27
# 2386  0.052             Reno, NV       Buckbean Brewing Company   40.0    26
# 2387  0.085       Santa Cruz, CA               Uncommon Brewers    NaN    25
# 2388  0.070        Pottstown, PA        Sly Fox Brewing Company  113.0    24
# 2389  0.053        Pottstown, PA        Sly Fox Brewing Company   21.0    23
# 2390  0.056        Pottstown, PA        Sly Fox Brewing Company   11.0    22
# 2391  0.049        Pottstown, PA        Sly Fox Brewing Company   44.0    21
# 2392  0.051        Pottstown, PA        Sly Fox Brewing Company   40.0    20
# 2393  0.040  Brooklyn Center, MN          Surly Brewing Company   37.0    19
# 2394  0.055  Brooklyn Center, MN          Surly Brewing Company   34.0    18
# 2395  0.051  Brooklyn Center, MN          Surly Brewing Company   45.0    17
# 2396  0.051  Brooklyn Center, MN          Surly Brewing Company   45.0    16
# 2397  0.097  Brooklyn Center, MN          Surly Brewing Company  120.0    15
# 2398  0.051  Brooklyn Center, MN          Surly Brewing Company   20.0    14
# 2399  0.067  Brooklyn Center, MN          Surly Brewing Company   33.0    13
# 2400  0.062  Brooklyn Center, MN          Surly Brewing Company   99.0    12
# 2401  0.083    San Francisco, CA         21st Amendment Brewery   35.0    11
# 2402  0.070    San Francisco, CA         21st Amendment Brewery   65.0    10
# 2403  0.049    San Francisco, CA         21st Amendment Brewery   17.0     9
# 2404  0.099         Longmont, CO            Oskar Blues Brewery   98.0     8
# 2405  0.053         Longmont, CO            Oskar Blues Brewery   35.0     7
# 2406  0.099         Longmont, CO            Oskar Blues Brewery  100.0     6
# 2407  0.080         Longmont, CO            Oskar Blues Brewery   35.0     5
# 2408  0.087         Longmont, CO            Oskar Blues Brewery   85.0     4
# 2409  0.065         Longmont, CO            Oskar Blues Brewery   65.0     1
#
#                                        name size(oz)  \
# 0                              Get Together      16
# 1                             Maggie's Leap      16
# 2                                Wall's End      16
# 3                                   Pumpion      16
# 4                                Stronghold      16
# 5                               Parapet ESB      16
# 6                            Citra Ass Down      16
# 7                            London Balling      16
# 8                                      35 K      16
# 9                                    A Beer      16
# 10                          Rules are Rules      16
# 11                            Flesh Gourd'n      16
# 12                                 Sho'nuff      16
# 13                              Bloody Show      16
# 14                              Rico Sauvin      16
# 15                         Coq de la Marche      16
# 16                           Kamen Knuddeln      16
# 17                             Pile of Face      16
# 18                           The Brown Note      16
# 19                              House Lager      16
# 20                             Leisure Time      12
# 21                               Excess IPL      16
# 22                           Hoponius Union      12
# 23                                 Calyptra      12
# 24                           Habitus (2014)      16
# 25                                    Solis      16
# 26                                 Jucundus      16
# 27                                  Habitus      16
# 28                                  Grazias      16
# 29                                 Claritas      16
# ...                                     ...      ...
# 2380                         CoCoNut Porter      12
# 2381                          Big Swell IPA      12
# 2382              Urban Wilderness Pale Ale      12
# 2383             Very Noddy Lager (Current)      16
# 2384            Tule Duck Red Ale (Current)      16
# 2385  Original Orange Blossom Ale (Current)      16
# 2386            Black Noddy Lager (Current)      16
# 2387                           Siamese twin      16
# 2388                                113 IPA      12
# 2389                           Dunkel Lager      12
# 2390                       Royal Weisse Ale      12
# 2391                          Pikeland Pils      12
# 2392                       Phoenix Pale Ale      12
# 2393                          Bitter Brewer      16
# 2394                              SurlyFest      16
# 2395                          Coffee Bender      16
# 2396                                 Bender      16
# 2397                           Abrasive Ale      16
# 2398                                   Hell      16
# 2399                               CynicAle      16
# 2400                                Furious      16
# 2401                           Monk's Blood      12
# 2402                  Brew Free! or Die IPA      12
# 2403          Hell or High Watermelon Wheat      12
# 2404                Ten Fidy Imperial Stout      12
# 2405               Mama's Little Yella Pils      12
# 2406                     GUBNA Imperial IPA      12
# 2407                               Old Chub      12
# 2408                      Gordon Ale (2009)      12
# 2409                        Dale's Pale Ale      12
#
#                                     style
# 0                            American IPA
# 1                      Milk / Sweet Stout
# 2                       English Brown Ale
# 3                             Pumpkin Ale
# 4                         American Porter
# 5     Extra Special / Strong Bitter (ESB)
# 6          American Double / Imperial IPA
# 7                      English Barleywine
# 8                      Milk / Sweet Stout
# 9                 American Pale Ale (APA)
# 10                        German Pilsener
# 11                            Pumpkin Ale
# 12                       Belgian Pale Ale
# 13                       American Pilsner
# 14         American Double / Imperial IPA
# 15                 Saison / Farmhouse Ale
# 16                      American Wild Ale
# 17                           American IPA
# 18                      English Brown Ale
# 19             Keller Bier / Zwickel Bier
# 20                    American Pale Lager
# 21              American India Pale Lager
# 22              American India Pale Lager
# 23              American India Pale Lager
# 24         American Double / Imperial IPA
# 25                           American IPA
# 26                              Wheat Ale
# 27         American Double / Imperial IPA
# 28                              Cream Ale
# 29                                 Kölsch
# ...                                   ...
# 2380                      American Porter
# 2381                         American IPA
# 2382                     English Pale Ale
# 2383                          Schwarzbier
# 2384             American Amber / Red Ale
# 2385                 Herbed / Spiced Beer
# 2386                          Schwarzbier
# 2387                               Dubbel
# 2388                         American IPA
# 2389                  Munich Dunkel Lager
# 2390                           Hefeweizen
# 2391                      German Pilsener
# 2392              American Pale Ale (APA)
# 2393                       English Bitter
# 2394                             Rye Beer
# 2395                   American Brown Ale
# 2396                   American Brown Ale
# 2397       American Double / Imperial IPA
# 2398           Keller Bier / Zwickel Bier
# 2399               Saison / Farmhouse Ale
# 2400                         American IPA
# 2401                     Belgian Dark Ale
# 2402                         American IPA
# 2403               Fruit / Vegetable Beer
# 2404               Russian Imperial Stout
# 2405                       Czech Pilsener
# 2406       American Double / Imperial IPA
# 2407                         Scottish Ale
# 2408       American Double / Imperial IPA
# 2409              American Pale Ale (APA)
#
# [2410 rows x 8 columns]
